# %% [markdown]
# <a href="https://colab.research.google.com/github/Yunkoo-GIT/Programming/blob/main/20201019.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
i=30

# %%
j=20

# %%
i+j
# Out:
# 50

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
iris_data = pd.read_csv("iris.csv")

# %%
covid19_data = pd.read_csv("covid19.csv")

# %%
iris_data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
iris_data.to_csv("lll.csv")

# %%
iris_data.plot.box()
# Out:
# <AxesSubplot:>

# %%
iris_data.plot.hist(bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris_data.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
iris_data.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'variety'],
#       dtype='object')

# %%
iris_data.values
# Out:
# array([[5.1, 3.5, 1.4, 0.2, 'Setosa'],
#        [4.9, 3.0, 1.4, 0.2, 'Setosa'],
#        [4.7, 3.2, 1.3, 0.2, 'Setosa'],
#        [4.6, 3.1, 1.5, 0.2, 'Setosa'],
#        [5.0, 3.6, 1.4, 0.2, 'Setosa'],
#        [5.4, 3.9, 1.7, 0.4, 'Setosa'],
#        [4.6, 3.4, 1.4, 0.3, 'Setosa'],
#        [5.0, 3.4, 1.5, 0.2, 'Setosa'],
#        [4.4, 2.9, 1.4, 0.2, 'Setosa'],
#        [4.9, 3.1, 1.5, 0.1, 'Setosa'],
#        [5.4, 3.7, 1.5, 0.2, 'Setosa'],
#        [4.8, 3.4, 1.6, 0.2, 'Setosa'],
#        [4.8, 3.0, 1.4, 0.1, 'Setosa'],
#        [4.3, 3.0, 1.1, 0.1, 'Setosa'],
#        [5.8, 4.0, 1.2, 0.2, 'Setosa'],
#        [5.7, 4.4, 1.5, 0.4, 'Setosa'],
#        [5.4, 3.9, 1.3, 0.4, 'Setosa'],
#        [5.1, 3.5, 1.4, 0.3, 'Setosa'],
#        [5.7, 3.8, 1.7, 0.3, 'Setosa'],
#        [5.1, 3.8, 1.5, 0.3, 'Setosa'],
#        [5.4, 3.4, 1.7, 0.2, 'Setosa'],
#        [5.1, 3.7, 1.5, 0.4, 'Setosa'],
#        [4.6, 3.6, 1.0, 0.2, 'Setosa'],
#        [5.1, 3.3, 1.7, 0.5, 'Setosa'],
# ...

# %%
iris_data.ndim
# Out:
# 2

# %%
iris_data.shape
# Out:
# (150, 5)

# %%
iris_data.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
iris_data.tail(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    variety
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica

# %%
iris_data.axes
# Out:
# [RangeIndex(start=0, stop=150, step=1),
#  Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#         'variety'],
#        dtype='object')]

# %%
iris_data.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# variety          object
# dtype: object

# %%
iris_data.info
# Out:
# <bound method DataFrame.info of      sepal_length  sepal_width  petal_length  petal_width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]>

# %%
iris_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   variety       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 5.3+ KB

# %%
iris_data[['sepal_length', 'sepal_width']]
# Out:
#      sepal_length  sepal_width
# 0             5.1          3.5
# 1             4.9          3.0
# 2             4.7          3.2
# 3             4.6          3.1
# 4             5.0          3.6
# ..            ...          ...
# 145           6.7          3.0
# 146           6.3          2.5
# 147           6.5          3.0
# 148           6.2          3.4
# 149           5.9          3.0
#
# [150 rows x 2 columns]

# %%
iris_data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris_data.count
# Out:
# <bound method DataFrame.count of      sepal_length  sepal_width  petal_length  petal_width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]>

# %%
iris_data.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
iris_data.cov()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      0.685694    -0.042434      1.274315     0.516271
# sepal_width      -0.042434     0.189979     -0.329656    -0.121639
# petal_length      1.274315    -0.329656      3.116278     1.295609
# petal_width       0.516271    -0.121639      1.295609     0.581006

# %%
iris_data.sepal_width.corr(iris_data.petal_width)
# Out:
# -0.3661259325364389

# %%
covid19_data
# Out:
#           date  Belgium  Brazil  Canada   China   France  Germany  India  \
# 0   2020-02-26      NaN     NaN     NaN  2717.0      2.0      NaN    NaN
# 1   2020-02-27      NaN     NaN     NaN  2746.0      2.0      NaN    NaN
# 2   2020-02-28      NaN     NaN     NaN  2790.0      2.0      NaN    NaN
# 3   2020-02-29      NaN     NaN     NaN  2837.0      2.0      NaN    NaN
# 4   2020-03-01      NaN     NaN     NaN  2872.0      2.0      NaN    NaN
# 5   2020-03-02      NaN     NaN     NaN  2914.0      3.0      NaN    NaN
# 6   2020-03-03      NaN     NaN     NaN  2947.0      4.0      NaN    NaN
# 7   2020-03-04      NaN     NaN     NaN  2983.0      4.0      NaN    NaN
# 8   2020-03-05      NaN     NaN     NaN  3015.0      6.0      NaN    NaN
# 9   2020-03-06      NaN     NaN     NaN  3044.0      9.0      NaN    NaN
# 10  2020-03-07      NaN     NaN     NaN  3072.0     11.0      NaN    NaN
# 11  2020-03-08      NaN     NaN     NaN  3100.0     19.0      NaN    NaN
# ...

# %%
covid19_data_drop = covid19_data.dropna()

# %%
iris_data.plot()
# Out:
# <AxesSubplot:>

# %%
iris_data.sepal_length.plot()
# Out:
# <AxesSubplot:>

# %%
iris_kk = iris_data[['petal_length', 'petal_width']]
iris_kk
# Out:
#      petal_length  petal_width
# 0             1.4          0.2
# 1             1.4          0.2
# 2             1.3          0.2
# 3             1.5          0.2
# 4             1.4          0.2
# ..            ...          ...
# 145           5.2          2.3
# 146           5.0          1.9
# 147           5.2          2.0
# 148           5.4          2.3
# 149           5.1          1.8
#
# [150 rows x 2 columns]

# %%
iris_kk.iloc[5].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
iris_kk.plot.bar()
# Out:
# <AxesSubplot:>

# %%
iris_data.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
iris_data.plot.barh(stacked=True)
# Out:
# <AxesSubplot:>

# %%
covid19_data_zero.plot.box()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-732b37e08050> in <module>
# ----> 1 covid19_data_zero.plot.box()
#
# NameError: name 'covid19_data_zero' is not defined

# %%
covid19_data_zero.boxplot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-4d58cfdf99a2> in <module>
# ----> 1 covid19_data_zero.boxplot()
#
# NameError: name 'covid19_data_zero' is not defined
